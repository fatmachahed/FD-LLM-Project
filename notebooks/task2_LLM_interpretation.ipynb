# %%
# import os
# import pandas as pd
# from groq import Groq

# # ============================================================
# # 1. Initialisation du client Groq
# # ============================================================
# client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

# MODEL_NAME = "llama-3.1-70b-versatile" # très bon pour raisonnement sémantique


# # ============================================================
# # 2. Prompt de jugement sémantique
# # ============================================================
# def ask_llm_about_fd(lhs, rhs, dataset_name):
#     """
#     Interroge le LLM pour juger la plausibilité sémantique d'une FD
#     """
#     fd_str = f"{', '.join(lhs)} -> {rhs}"

#     prompt = f"""
# You are a data semantics expert.

# Dataset: {dataset_name}

# Functional Dependency:
# {fd_str}

# Question:
# Does this dependency make sense in the real world?

# Choose ONE label among:
# - meaningful
# - accidental
# - encoding-based
# - degenerate
# - unlikely

# Then give a short explanation (2–3 sentences).

# Answer format:
# Label: <label>
# Explanation: <text>
# """

#     response = client.chat.completions.create(
#         model=MODEL_NAME,
#         messages=[{"role": "user", "content": prompt}],
#         temperature=0.2
#     )

#     return response.choices[0].message.content.strip()


# # ============================================================
# # 3. Analyse d'un dataset (Task 2)
# # ============================================================
# def task2_analyze_fds(dataset_name, fds, human_judgments):
#     """
#     human_judgments : dict
#       clé   = "A, B -> C"
#       valeur = jugement humain
#     """

#     results = []

#     for lhs, rhs in fds:
#         fd_str = f"{', '.join(lhs)} -> {rhs}"

#         llm_answer = ask_llm_about_fd(lhs, rhs, dataset_name)

#         # Extraction simple du label
#         llm_label = "unknown"
#         for label in ["meaningful", "accidental", "encoding-based", "degenerate", "unlikely"]:
#             if label in llm_answer.lower():
#                 llm_label = label
#                 break

#         human_label = human_judgments.get(fd_str, "not provided")
#         agreement = "Yes" if llm_label == human_label else "No"

#         results.append({
#             "FD": fd_str,
#             "LLM judgment": llm_label,
#             "Your judgment": human_label,
#             "Agreement?": agreement
#         })

#     return pd.DataFrame(results)


# # ============================================================
# # 4. Exemple : IRIS
# # ============================================================

# fds_iris = [
#     (["petal_length_in_cm", "petal_width_in_cm"], "class"),
#     (["petal_length_in_cm", "sepal_length_in_cm"], "class"),
#     (["petal_width_in_cm", "sepal_width_in_cm"], "class"),
#     (["sepal_length_in_cm", "sepal_width_in_cm", "petal_length_in_cm"], "class"),
#     (["petal_width_in_cm", "petal_length_in_cm", "sepal_width_in_cm"], "class"),
#     (["petal_width_in_cm", "petal_length_in_cm", "sepal_length_in_cm"], "class"),
# ]

# # Jugement HUMAIN (obligatoire pour Task 2)
# human_judgments_iris = {
#     "petal_length_in_cm, petal_width_in_cm -> class": "meaningful",
#     "petal_length_in_cm, sepal_length_in_cm -> class": "meaningful",
#     "petal_width_in_cm, sepal_width_in_cm -> class": "meaningful",
#     "sepal_length_in_cm, sepal_width_in_cm, petal_length_in_cm -> class": "accidental",
#     "petal_width_in_cm, petal_length_in_cm, sepal_width_in_cm -> class": "accidental",
#     "petal_width_in_cm, petal_length_in_cm, sepal_length_in_cm -> class": "accidental",
# }

# df_task2_iris = task2_analyze_fds(
#     dataset_name="IRIS",
#     fds=fds_iris,
#     human_judgments=human_judgments_iris
# )

# print(df_task2_iris)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 116
#     106 # Jugement HUMAIN (obligatoire pour Task 2)
#     107 human_judgments_iris = {
#     108     "petal_length_in_cm, petal_width_in_cm -> class": "meaningful",
#     109     "petal_length_in_cm, sepal_length_in_cm -> class": "meaningful",
#    (...)
#     113     "petal_width_in_cm, petal_length_in_cm, sepal_length_in_cm -> class": "accidental",
#     114 }
# --> 116 df_task2_iris = task2_analyze_fds(
#     117     dataset_name="IRIS",
#     118     fds=fds_iris,
#     119     human_judgments=human_judgments_iris
#     120 )
#     122 print(df_task2_iris)
#
# Cell In[5], line 71, in task2_analyze_fds(dataset_name, fds, human_judgments)
#      68 for lhs, rhs in fds:
#      69     fd_str = f"{', '.join(lhs)} -> {rhs}"
# ---> 71     llm_answer = ask_llm_about_fd(lhs, rhs, dataset_name)
# ...

# %%
pip install groq
# Out:
# ...
#   Using cached groq-1.0.0-py3-none-any.whl.metadata (16 kB)
# ...
# Using cached groq-1.0.0-py3-none-any.whl (138 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
